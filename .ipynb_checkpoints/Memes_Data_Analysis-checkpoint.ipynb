# %%
import pandas as pd
import numpy as np
import datetime
import time
import csv
import dateutil.relativedelta
import matplotlib.pyplot as plt; plt.rcdefaults()
from sklearn.linear_model import LinearRegression
from scipy import stats
import statsmodels.formula.api as sm

# %%
df = pd.read_pickle("final_memes.pkl")

# %%
np.mean(df['Half_Life'])
df[df['year']==2019]['Half_Life']
df['Peak_Date'].iloc[0].year
np.mean(df[df['year']==2019]['fHalf_Life'])
df[df['year']==2019]['fHalf_Life']
# Out:
# 1       21.0
# 4        7.0
# 5        7.0
# 6       14.0
# 7       14.0
#         ...
# 1612     7.0
# 1631    14.0
# 1633     7.0
# 1635    42.0
# 1653     7.0
# Name: fHalf_Life, Length: 157, dtype: float64

# %%
df.loc[df['Half_Life']==max(df['Half_Life'])]
# Out:
#        Peak_Date                 Title Half_Life  fHalf_Life  fPeak_Date  \
# 329   2017-01-15  pumped up kicks meme  147 days       147.0      736344
# 1056  2012-01-22   ancient aliens meme  147 days       147.0      734524
#
#       year  Ordinal_Peak
# 329   2017          4403
# 1056  2012          2583

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(df['Ordinal_Peak'],df['fHalf_Life'])

plt.show()

# %%
df['Ordinal_Peak']
# Out:
# 0       4760
# 1       5222
# 2       5068
# 3       5061
# 4       5369
#         ...
# 1662    2534
# 1663    5082
# 1664    1099
# 1665    2065
# 1666    3451
# Name: Ordinal_Peak, Length: 1667, dtype: int64

# %%
eList = []
for x in range(2012,2021):
    eList.append(df[df['year']==x]['Half_Life'].mean().total_seconds()/ datetime.timedelta(days=1).total_seconds())

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(eList, color = 'red')
ax.bar(['2012','2013','2014','2015','2016','2017','2018','2019','2020'],eList)
ax.grid()
ax.set_ylabel('Lifetime in Days')
ax.set_xlabel('Year')
ax.set_title('Average Lifetime of Memes per Year')
plt.show()

# %%
stats.ttest_ind(df[df['year']==2019]['fHalf_Life'], df[df['year']==2018]['fHalf_Life'])
# Out:
# Ttest_indResult(statistic=2.1022436794538537, pvalue=0.0362521231910508)

# %%
df.boxplot('fHalf_Life', by='year') #boxplot for the data. It doesn't work for this kind of data, but I thought it is worth leaving this up here.
# Out:
# <AxesSubplot:title={'center':'fHalf_Life'}, xlabel='year'>
